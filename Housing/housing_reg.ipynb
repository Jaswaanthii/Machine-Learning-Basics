# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns 
#import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline
from numpy import std, mean

import sklearn
from sklearn import datasets, linear_model, metrics
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
df=pd.read_csv("C:/Users/#######/Downloads/Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
x = df.drop('price', axis=1)
x
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
y = df['price']
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=20)

# %%
lr = LinearRegression()
rf = RandomForestRegressor(max_depth=5, random_state=2) #increase max_depth for better accuracy
br = linear_model.BayesianRidge()

x_train1 = x_train
y_train1 = y_train
x_test1 = x_test
y_test1 = y_test

x_train2 = x_train
y_train2 = y_train
x_test2 = x_test
y_test2 = y_test

x_train3 = x_train
y_train3 = y_train
x_test3 = x_test
y_test3 = y_test


x_train1, y_train1 = make_regression(n_samples=1000, n_features=9, n_informative=20, noise=0.5, random_state=2)
x_test1, y_test1 = make_regression(n_samples=1000, n_features=9, n_informative=20, noise=0.5, random_state=2)

x_train2, y_train2 = make_regression(n_samples=1000, n_features=9, n_informative=20, noise=0.5, random_state=2)
x_test2, y_test2 = make_regression(n_samples=1000, n_features=9, n_informative=20, noise=0.5, random_state=2)

x_train3, y_train3 = make_regression(n_samples=1000, n_features=9, n_informative=20, noise=0.5, random_state=2)
x_test3, y_test3 = make_regression(n_samples=1000, n_features=9, n_informative=20, noise=0.5, random_state=2)

# %%
lr.fit(x_train1, y_train1)
# Out:
# LinearRegression()

# %%
y_predLR = lr.predict(x_test1)
r2scoreLR = r2_score(y_test1, y_predLR)
r2scoreLR
# Out:
# 0.9999912938133745

# %%
rf.fit(x_train2, y_train2)
# Out:
# RandomForestRegressor(max_depth=5, random_state=2)

# %%
y_predRFR = rf.predict(x_test2)
r2scoreRFR = r2_score(y_test2, y_predRFR)
r2scoreRFR
# Out:
# 0.8389529739047711

# %%
br.fit(x_train3, y_train3)
# Out:
# BayesianRidge()

# %%
y_predBR = br.predict(x_test3)
r2scoreBR = r2_score(y_test3, y_predBR)
r2scoreBR
# Out:
# 0.9999912938133682
