# %%
import pandas as pd

# %%
# Read csv
df = pd.read_csv("C:/Users/jpadmanabhan/Downloads/covdata.csv")

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
#!pip3 install movecolumn

# %%
# Move column to last
import movecolumn as mc
mc.MoveToLast(df,'CLASIFFICATION_FINAL')
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# ICU                     0
# CLASIFFICATION_FINAL    0
# dtype: int64

# %%
# Correlation of columns w.r.t. target column
df[df.columns[:]].corr()['CLASIFFICATION_FINAL']
# Out:
# USMER                   0.028840
# MEDICAL_UNIT            0.079981
# SEX                    -0.057782
# PATIENT_TYPE           -0.183370
# INTUBED                 0.193075
# PNEUMONIA               0.075351
# AGE                    -0.152637
# PREGNANT               -0.057809
# DIABETES               -0.004739
# COPD                   -0.010336
# ASTHMA                 -0.011178
# INMSUPR                -0.009412
# HIPERTENSION           -0.006020
# OTHER_DISEASE          -0.011143
# CARDIOVASCULAR         -0.012143
# OBESITY                -0.006924
# RENAL_CHRONIC          -0.011342
# TOBACCO                -0.012567
# ICU                     0.193163
# CLASIFFICATION_FINAL    1.000000
# Name: CLASIFFICATION_FINAL, dtype: float64

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
# Replacing these values with 0 as they are null (mentioned in dataset description)
df = df.replace(97, 0)
df = df.replace(98, 0)
df = df.replace(99, 0)

# %%
# Removing the 9999-99-99 because it is null value
df['DATE_DIED'] = df['DATE_DIED'].str[-4:]

# %%
df.head(10)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  INTUBED  PNEUMONIA  AGE  \
# 0      2             1    1             1      2020        0          1   65
# 1      2             1    2             1      2020        0          1   72
# 2      2             1    2             2      2020        1          2   55
# 3      2             1    1             1      2020        0          2   53
# 4      2             1    2             1      2020        0          2   68
# 5      2             1    1             2      9-99        2          1   40
# 6      2             1    1             1      9-99        0          2   64
# 7      2             1    1             1      9-99        0          1   64
# 8      2             1    1             2      9-99        2          2   37
# 9      2             1    1             2      9-99        2          2   25
#
#    PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
df['DATE_DIED'] = df['DATE_DIED'].replace('9-99', 0)

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  INTUBED  PNEUMONIA  \
# 0            2             1    1             1      2020        0          1
# 1            2             1    2             1      2020        0          1
# 2            2             1    2             2      2020        1          2
# 3            2             1    1             1      2020        0          2
# 4            2             1    2             1      2020        0          2
# ...        ...           ...  ...           ...       ...      ...        ...
# 1048570      2            13    2             1         0        0          2
# 1048571      1            13    2             2         0        2          2
# 1048572      2            13    2             1         0        0          2
# 1048573      2            13    2             1         0        0          2
# 1048574      2            13    2             1         0        0          2
#
# ...

# %%
df.dtypes
# Out:
# USMER                    int64
# MEDICAL_UNIT             int64
# SEX                      int64
# PATIENT_TYPE             int64
# DATE_DIED               object
# INTUBED                  int64
# PNEUMONIA                int64
# AGE                      int64
# PREGNANT                 int64
# DIABETES                 int64
# COPD                     int64
# ASTHMA                   int64
# INMSUPR                  int64
# HIPERTENSION             int64
# OTHER_DISEASE            int64
# CARDIOVASCULAR           int64
# OBESITY                  int64
# RENAL_CHRONIC            int64
# TOBACCO                  int64
# ICU                      int64
# CLASIFFICATION_FINAL     int64
# dtype: object

# %%
#Changing data type of date from object to int
df['DATE_DIED'] = df['DATE_DIED'].astype(int)

# %%
df['DATE_DIED'].unique().tolist()
# Out:
# [2020, 0, 2021]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#df['DATE_DIED'] = le.fit_transform(df['DATE_DIED'])
# Separating CLASIFFICATION_FINAL as 0 and 1, 1 for above 3(not affected) and 0 for affected
df["DATE_DIED"] = np.where(df["DATE_DIED"] == 0, 0, 1)

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  PNEUMONIA  AGE  \
# 0      2             1    1             1          1        0          1   65
# 1      2             1    2             1          1        0          1   72
# 2      2             1    2             2          1        1          2   55
# 3      2             1    1             1          1        0          2   53
# 4      2             1    2             1          1        0          2   68
#
#    PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2  ...       2        2             1              2
# 1         0         2  ...       2        2             1              2
# 2         0         1  ...       2        2             2              2
# 3         2         2  ...       2        2             2              2
# 4         0         1  ...       2        2             1              2
#
# ...

# %%
df['CLASIFFICATION_FINAL'].unique().tolist()
# Out:
# [3, 5, 7, 6, 1, 2, 4]

# %%
import numpy as np

# Separating age as 0 and 1, 1 for above 18 and 0 for less
df["AGE"] = np.where(df["AGE"] < 18, 0, 1)

# %%
# Separating CLASIFFICATION_FINAL as 0 and 1, 1 for above 3(not affected) and 0 for affected
df["CLASIFFICATION_FINAL"] = np.where(df["CLASIFFICATION_FINAL"] < 3, 0, 1)

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  \
# 0            2             1    1             1          1        0
# 1            2             1    2             1          1        0
# 2            2             1    2             2          1        1
# 3            2             1    1             1          1        0
# 4            2             1    2             1          1        0
# ...        ...           ...  ...           ...        ...      ...
# 1048570      2            13    2             1          0        0
# 1048571      1            13    2             2          0        2
# 1048572      2            13    2             1          0        0
# 1048573      2            13    2             1          0        0
# 1048574      2            13    2             1          0        0
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1    1         2         2  ...       2        2
# ...

# %%
df[df.columns[:]].corr()['CLASIFFICATION_FINAL']
# Out:
# USMER                  -0.010578
# MEDICAL_UNIT           -0.012624
# SEX                    -0.010747
# PATIENT_TYPE           -0.046256
# DATE_DIED              -0.075071
# INTUBED                -0.042462
# PNEUMONIA               0.026448
# AGE                    -0.003613
# PREGNANT                0.010685
# DIABETES                0.020635
# COPD                    0.012585
# ASTHMA                  0.002917
# INMSUPR                 0.009264
# HIPERTENSION            0.017587
# OTHER_DISEASE           0.005266
# CARDIOVASCULAR          0.012601
# OBESITY                 0.004315
# RENAL_CHRONIC           0.013018
# TOBACCO                 0.005417
# ICU                    -0.046978
# CLASIFFICATION_FINAL    1.000000
# Name: CLASIFFICATION_FINAL, dtype: float64

# %%
from sklearn.feature_selection import chi2

x = df.drop('DATE_DIED',axis=1)
y = df['DATE_DIED']

chi_scores = chi2(x, y)
chi_scores
# 1st array is chi values and second array is p-value
# Out:
# (array([1.89637338e+03, 3.59493295e+04, 1.15806609e+03, 3.61361759e+04,
#         2.93419600e+05, 1.39730865e+04, 1.43074887e+02, 6.46670879e+03,
#         3.01282130e+03, 1.07588834e+02, 1.28479820e-01, 4.74709256e+01,
#         3.37806237e+03, 1.04019382e+02, 1.09478002e+02, 3.26928447e+02,
#         1.98216008e+02, 1.40032716e+01, 4.05222417e+05, 5.89037543e+01]),
#  array([0.00000000e+000, 0.00000000e+000, 7.92213493e-254, 0.00000000e+000,
#         0.00000000e+000, 0.00000000e+000, 5.66053223e-033, 0.00000000e+000,
#         0.00000000e+000, 3.30743442e-025, 7.20013450e-001, 5.58258239e-012,
#         0.00000000e+000, 2.00346576e-024, 1.27511813e-025, 4.48523292e-073,
#         5.11855410e-045, 1.82492828e-004, 0.00000000e+000, 1.65575997e-014]))

# %%
p_values = pd.Series(chi_scores[1],index = x.columns)
p_values.sort_values(ascending = False , inplace = True)

# Value with highest val is the least important as it is very independent
p_values.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Removing columns with 0.004 etc correlation value
df.drop(["ASTHMA"], axis=1, inplace=True)

# %%
# import matplotlib.pyplot as plt

# df.plot(kind="bar", x="CLASIFFICATION_FINAL", y="DATE_DIED")
# plt.show()

# %%
x = df.drop('DATE_DIED', axis=1)
x
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0            2             1    1             1        0          1    1
# 1            2             1    2             1        0          1    1
# 2            2             1    2             2        1          2    1
# 3            2             1    1             1        0          2    1
# 4            2             1    2             1        0          2    1
# ...        ...           ...  ...           ...      ...        ...  ...
# 1048570      2            13    2             1        0          2    1
# 1048571      1            13    2             2        2          2    1
# 1048572      2            13    2             1        0          2    1
# 1048573      2            13    2             1        0          2    1
# 1048574      2            13    2             1        0          2    1
#
#          PREGNANT  DIABETES  COPD  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
y = df["DATE_DIED"]
y
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 1048570    0
# 1048571    0
# 1048572    0
# 1048573    0
# 1048574    0
# Name: DATE_DIED, Length: 1048575, dtype: int32

# %%
y.unique()
# Out:
# array([1, 0])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((838860, 19), (209715, 19), (838860,), (209715,))

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import utils

scalerxtr = StandardScaler().fit(x_train)
xtr_scaled = scalerxtr.transform(x_train)

scalerxt = StandardScaler().fit(x_test)
xt_scaled = scalerxtr.transform(x_test)

y_train1= y_train.values.reshape(-1, 1)
scalerytr = StandardScaler().fit(y_train1)
ytr_scaled = scalerytr.transform(y_train1)

y_test1= y_test.values.reshape(-1, 1)
scaleryt = StandardScaler().fit(y_test1)
yt_scaled = scaleryt.transform(y_test1)

print(utils.multiclass.type_of_target(yt_scaled))
# Out:
# continuous

# %%
from sklearn.linear_model import LogisticRegression
import sklearn 

lr = LogisticRegression(max_iter=1000)
#lr.fit(x_train, y_train)
#ytr_scaled = column_or_1d(ytr_scaled, warn=True)
ytr_scaled = le.fit_transform(ytr_scaled)
lr.fit(xtr_scaled, ytr_scaled)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pipe = make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000))
pipe.fit(x_train, y_train)  # apply scaling on training data
pipe.score(x_test, y_test)  # apply scaling on testing data, without leaking training data.
#0.9427651813175023
# Out:
# 0.9416875283122332

# %%
ypredlr = lr.predict(xt_scaled)
yt_scaled = le.fit_transform(yt_scaled)
acclr = sklearn.metrics.accuracy_score(yt_scaled, ypredlr)
#acclr = lr.score(xt_scaled, yt_scaled)
acclr
0.6615168204467968
# Out:
# 0.6615168204467968

# %%
ypredlr
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(max_depth=5, random_state=5)
rfc.fit(xtr_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=5)

# %%
ypredrfc = rfc.predict(xt_scaled)
accrfc = sklearn.metrics.accuracy_score(y_test, ypredrfc)
accrfc
0.6609779939441623
# Out:
# 0.6609779939441623

# %%
import xgboost as xgb1

xgb = xgb1.XGBClassifier(learning_rate=0.3, objective="reg:logistic")
xgb.fit(xtr_scaled, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.3, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, objective='reg:logistic', predictor='auto', ...)

# %%
ypredxgb = xgb.predict(xt_scaled)
accxgb = sklearn.metrics.accuracy_score(y_test, ypredxgb)
accxgb
#0.67129675988842
# Out:
# 0.6713015282645495
